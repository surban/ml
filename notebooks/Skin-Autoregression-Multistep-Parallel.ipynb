# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from ml.apps.skin.timeseries import *
from ml.apps.skin.workingset import *
from ml.simple.table import *
from ml.datasets.skin import SkinDataset
from ml.common.util import ParameterHistory
from ml.common.test import check_gradient, check_directional_gradient
from climin.gd import GradientDescent
from climin.bfgs import Bfgs, Lbfgs
from climin.rmsprop import RmsProp


ws = SkinWorkingset("raising_small", (1,1))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Dataset Z:\dev\indentor\indentor\apps\out\raising_small.skn:
#      taxel          train   validation   test
#      1,1            800     100          100
#      3,2            785      98           98
# Avg. datapoints per record: 2433
# Sampling interval:          0.01 s
#
# Using taxel  (1, 1)
#
# trn: next step:          1945207 steps
# trn: curves:             800
# val: next step:          246044 steps
# val: curves:             100
# tst: next step:          244160 steps
# tst: curves:             100

# %% [markdown]
# # Pretraining using matrix inversion

# %%
tr = SmoothTableRegression([ws.force_min, ws.skin_min], 
                           [ws.force_step, ws.skin_step], 
                           [ws.force_max, ws.skin_max])
print "Number of weights: %d" % tr.weight_matrix.size

start_weights = np.load("skin-table-start-weights.npz")['optimal_weights']
tr.weights = start_weights.copy()

err = ws.error(tr)
for prt in ['trn', 'val', 'tst']:
    print "%s:   next step: %.7f;  all steps: %.5f;  failed curves: %d" % (prt, err['ns_'+prt], err['ms_'+prt], len(err['failed_'+prt]))
# Out:
# Number of weights: 26416
# trn:   next step: 0.0000090;  all steps: 0.19162;  failed curves: 152
# val:   next step: 0.0000147;  all steps: 0.16122;  failed curves: 15
# tst:   next step: 0.0002046;  all steps: 0.18897;  failed curves: 17

# %% [markdown]
# # Multistep training

# %%
err = ws.error(tr)
m_force, m_skin, m_valid = split_multicurves(ws.force['trn'][:, err['failed_trn']],
                                             ws.skin['trn'][:, err['failed_trn']],
                                             ws.valid['trn'][:, err['failed_trn']],
                                             split_steps=30, overlap=15)
msws = SkinMultistepWorkingset(ws, tr, m_force, m_skin, m_valid, batch_size=1000)
# Out:
# Number of multistep samples:  1249
# Number of batches:            1
# Batch size:                   1000

# %%
nplot = 20
f,v,s = msws.get_fvs(4)
figsize(20,10)
plot_multicurve_time(f[:, 0:nplot], s[:, 0:nplot], v[:, 0:nplot], None, timestep=ws.ds.timestep)

# %% [markdown]
# ### RMSprop

# %%
tr.weights = start_weights.copy()

# %%
his_failed = ParameterHistory(min_iters=100000)
his_ns = ParameterHistory(show_progress=False)
his_ms = ParameterHistory(show_progress=False)
figsize(10,5)

msws.batch = 0
opt = RmsProp(tr.weights, msws.gradient_wrapper, steprate=1e-6)
for iter, info in enumerate(opt):
    msws.next_batch()
    
    if iter % 100 == 0:        
        err = ws.error(tr)
        his_ns.add(iter, tr.weights, err['ns_trn'], err['ns_val'], err['ns_tst'])
        his_ms.add(iter, tr.weights, err['ms_trn'], err['ms_val'], err['ms_tst'])
        his_failed.add(iter, tr.weights, len(err['failed_trn']), len(err['failed_val']), len(err['failed_tst']))                  
        
        plt.clf()
        his_failed.plot(final=False, logscale=False)
        plt.show()
        
    if his_failed.should_terminate:
        break
        
end_weights = tr.weights.copy()
np.savez_compressed("multistep-parallel.npz", weights=end_weights)
# Out:
# <pre>1500: training:   5.00000  validation:   1.00000 (best:   1.00000)  test:   3.00000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-1cf322b4fbc5> in <module>()
#       6 msws.batch = 0
#       7 opt = RmsProp(tr.weights, msws.gradient_wrapper, steprate=1e-6)
# ----> 8 for iter, info in enumerate(opt):
#       9     msws.next_batch()
#      10
#
# y:\dev\climin\climin\rmsprop.pyc in __iter__(self)
#     174             self.wrt -= step1
#     175
# --> 176             gradient = self.fprime(self.wrt, *args, **kwargs)
#     177
#     178             st.moving_mean_squared = (
#
# Z:\dev\ml\ml\apps\skin\workingset.pyc in gradient_wrapper(self, dummy)
#      97     def gradient_wrapper(self, dummy):
#      98         f,v,s = self.get_fvs()
# ---> 99         return multistep_gradient(self.tr.predict_and_gradient, f, s, v)
#     100
#     101
#
# Z:\dev\ml\ml\apps\skin\timeseries.pyc in multistep_gradient(predictor_with_grad, force, skin, valid)
#     236                 skin_wrt_weights = pred_wrt_weights + pred_wrt_prev[0,0] * skin_wrt_weights
#     237             else:
# --> 238                 skin_wrt_weights = pred_wrt_weights + skin_wrt_weights.multiply(pred_wrt_prev)
#     239
#     240         # calculate gradient of error function
#
# C:\Anaconda\lib\site-packages\scipy\sparse\compressed.py in multiply(self, other)
#     453                 other = dia_matrix((other.toarray().ravel(), [0]),
#     454                                     shape=(other.shape[1], other.shape[1]))
# --> 455                 return self._mul_sparse_matrix(other)
#     456             # self is a row.
#     457             elif self.shape[0] == 1 and self.shape[1] == other.shape[1]:
#
# C:\Anaconda\lib\site-packages\scipy\sparse\compressed.py in _mul_sparse_matrix(self, other)
#     511         indptr = np.empty(major_axis + 1, dtype=np.intc)
#     512
# --> 513         other = self.__class__(other)  # convert to this format
#     514         fn = getattr(sparsetools, self.format + '_matmat_pass1')
#     515         fn(M, N, self.indptr, self.indices,
#
# C:\Anaconda\lib\site-packages\scipy\sparse\compressed.py in __init__(self, arg1, shape, dtype, copy)
#      27                 arg1 = arg1.copy()
#      28             else:
# ---> 29                 arg1 = arg1.asformat(self.format)
#      30             self._set_self(arg1)
#      31
#
# C:\Anaconda\lib\site-packages\scipy\sparse\base.py in asformat(self, format)
#     211             return self
#     212         else:
# --> 213             return getattr(self,'to' + format)()
#     214
#     215     ###################################################################
#
# C:\Anaconda\lib\site-packages\scipy\sparse\dia.py in tocsr(self)
#     190     def tocsr(self):
#     191         #this could be faster
# --> 192         return self.tocoo().tocsr()
#     193
#     194     def tocsc(self):
#
# C:\Anaconda\lib\site-packages\scipy\sparse\dia.py in tocoo(self)
#     204
#     205         for i,k in enumerate(self.offsets):
# --> 206             row[i,:] -= k
#     207
#     208         row,col,data = row.ravel(),col.ravel(),self.data.ravel()
#
# KeyboardInterrupt:

# %% [markdown]
# ## Alternative multistep training

# %%
msws_alt = SkinMultistepAlternativeWorkingset(ws, tr, ws.force['trn'], ws.skin['trn'], ws.valid['trn'], steps=10)
# Out:
# Steps:                        10

# %%
tr.weights = start_weights.copy()

# %%
his_failed = ParameterHistory(min_iters=100000)
his_ns = ParameterHistory(show_progress=False)
his_ms = ParameterHistory(show_progress=False)
figsize(10,5)

msws_alt.start_step = 0
opt = RmsProp(tr.weights, msws_alt.gradient_wrapper, steprate=1e-6)
for iter, info in enumerate(opt):
    msws_alt.next_batch()
    
    if iter % 100 == 0:        
        err = ws.error(tr)
        his_ns.add(iter, tr.weights, err['ns_trn'], err['ns_val'], err['ns_tst'])
        his_ms.add(iter, tr.weights, err['ms_trn'], err['ms_val'], err['ms_tst'])
        his_failed.add(iter, tr.weights, len(err['failed_trn']), len(err['failed_val']), len(err['failed_tst']))                  
        
        plt.clf()
        his_failed.plot(final=False, logscale=False)
        plt.show()
        
    if his_failed.should_terminate:
        break
        
end_weights = tr.weights.copy()
np.savez_compressed("multistep-parallel-alt.npz", weights=end_weights)
# Out:
# <pre>100000: training: 104.00000  validation:  10.00000 (best:   9.00000)  test:  11.00000

# %% [markdown]
# # Multistep prediction

# %%
end_weights = np.load("multistep-parallel.npz")['weights']
tr.weights = end_weights.copy()

# %%
err = ws.error(tr)
failed_force = ws.force['trn'][:, err['failed_trn']]
failed_skin = ws.skin['trn'][:, err['failed_trn']]
failed_valid = ws.valid['trn'][:, err['failed_trn']]
failed_skin_p = multistep_predict(tr.predict, failed_force, failed_valid, failed_skin[0, :])
figsize(14,7)
plot_multicurve_time(failed_force, failed_skin, failed_valid, failed_skin_p, timestep=ws.ds.timestep)
print failed_force.shape
# Out:
# (3018L, 16L)

# %%
print failed_test_curves(tr.weights)
test_skin_p = multistep_predict(tr.predict, test_force, test_valid, test_skin[0, :])
figsize(20,15)
plot_multicurve_time(test_force, test_skin, test_valid, test_skin_p, timestep=ds.timestep)
# Out:
# 6

# %%
tr_one = SmoothTableRegression([force_min, skin_min], 
                               [force_step, skin_step], 
                               [force_max, skin_max])
tr_one.weights = start_weights.copy()

test_skin_p = multistep_predict(tr_one.predict, test_force, test_valid, test_skin[0, :])
figsize(20,15)
plot_multicurve_time(test_force, test_skin, test_valid, test_skin_p, timestep=ds.timestep)
