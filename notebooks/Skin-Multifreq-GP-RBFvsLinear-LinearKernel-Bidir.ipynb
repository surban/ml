# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import GPy as gpy

import ml.apps.skin.timeseries
from ml.apps.skin.timeseries import *
from ml.apps.skin.workingset import *
from ml.simple.conditional_chain import *
from ml.datasets.skin import SkinDataset
from ml.common.util import ParameterHistory
from ml.common.test import check_gradient, check_directional_gradient

ml.apps.skin.timeseries.max_force = 10
# Out:
# common.gpu uses GPU:  False

# %% [markdown]
# ## Dataset

# %%
ws_linear_bidir = SkinWorkingset("mf_linear_bidir_10", taxel=(0,6))
ws_linear_raising = SkinWorkingset("mf_linear_raising_10", taxel=(0,6))

ws_random_raising = SkinWorkingset("mf_random_raising_10", taxel=(0,6))
ws_random_bidir = SkinWorkingset("mf_random_bidir_10", taxel=(0,6))
# Out:
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_linear_bidir_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 38
# Sampling interval:          1 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   0.213234
# maximum force:   9.738249
# minimum skin:    -1.670687
# maximum skin:    4.811076
#
# force step:   0.095250
# skin step:    0.064818
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_linear_raising_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 19
# Sampling interval:          1 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   0.641865
# maximum force:   9.734317
# minimum skin:    -1.669979
# maximum skin:    4.805637
#
# force step:   0.090925
# skin step:    0.064756
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_random_raising_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 17
# Sampling interval:          0.666667 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   -0.100000
# maximum force:   8.456289
# minimum skin:    -1.669744
# maximum skin:    4.809771
#
# force step:   0.085563
# skin step:    0.064795
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_random_bidir_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 17
# Sampling interval:          0.625 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   -0.100000
# maximum force:   8.495613
# minimum skin:    -1.664976
# maximum skin:    4.807362
#
# force step:   0.085956
# skin step:    0.064723

# %% [markdown]
# ## Training

# %%
ws_trn = ws_linear_bidir

#kernel = gpy.kern.rbf(ws_trn.n_features, ARD=False)
kernel = gpy.kern.linear(ws_trn.n_features, ARD=True)
X = ws_trn.flat_skin['trn'].T
Y = ws_trn.flat_force['trn'][:, np.newaxis]
gp = gpy.models.GPRegression(X, Y, kernel)

gp.optimize_restarts()
#gp.randomize()
#gp.optimize()
print gp
# Out:
# Optimization restart 1/10, f = 465.844091119
# Optimization restart 2/10, f = 475.897850802
# Optimization restart 3/10, f = 469.308316282
# Optimization restart 4/10, f = 424.833490743
# Optimization restart 5/10, f = 439.421821468
# Optimization restart 6/10, f = 445.380628948
# Optimization restart 7/10, f = 453.376245448
# Optimization restart 8/10, f = 654.554259354
# Optimization restart 9/10, f = 484.760873579
# Optimization restart 10/10, f = 435.340490856
# Log-likelihood: -4.248e+02
#
#          Name         |  Value   |  Constraints  |  Ties  |  prior
# --------------------------------------------------------------------
#   linear_variance_0   |  0.7379  |     (+ve)     |        |
#   linear_variance_1   |  0.2575  |     (+ve)     |        |
#   linear_variance_2   |  1.2019  |     (+ve)     |        |
#   linear_variance_3   |  0.3132  |     (+ve)     |        |
#   linear_variance_4   |  0.1934  |     (+ve)     |        |
#   linear_variance_5   |  1.4541  |     (+ve)     |        |
#   linear_variance_6   |  0.8641  |     (+ve)     |        |
#   linear_variance_7   |  1.2560  |     (+ve)     |        |
#   linear_variance_8   |  0.8652  |     (+ve)     |        |
#   linear_variance_9   |  1.2107  |     (+ve)     |        |
#   linear_variance_10  |  0.4197  |     (+ve)     |        |
#   linear_variance_11  |  0.3042  |     (+ve)     |        |
#   linear_variance_12  |  1.0909  |     (+ve)     |        |
#   linear_variance_13  |  0.3700  |     (+ve)     |        |
#   linear_variance_14  |  0.4067  |     (+ve)     |        |
#   linear_variance_15  |  0.4911  |     (+ve)     |        |
#   linear_variance_16  |  0.7019  |     (+ve)     |        |
#   linear_variance_17  |  0.5317  |     (+ve)     |        |
#   linear_variance_18  |  0.2254  |     (+ve)     |        |
#   linear_variance_19  |  0.4222  |     (+ve)     |        |
#   linear_variance_20  |  0.1028  |     (+ve)     |        |
#   linear_variance_21  |  1.0539  |     (+ve)     |        |
#   linear_variance_22  |  0.1836  |     (+ve)     |        |
#   linear_variance_23  |  0.2862  |     (+ve)     |        |
#   linear_variance_24  |  0.7196  |     (+ve)     |        |
#   linear_variance_25  |  0.3902  |     (+ve)     |        |
#   linear_variance_26  |  1.7367  |     (+ve)     |        |
#   linear_variance_27  |  0.2425  |     (+ve)     |        |
#   linear_variance_28  |  0.8356  |     (+ve)     |        |
#   linear_variance_29  |  0.6737  |     (+ve)     |        |
#   linear_variance_30  |  0.2708  |     (+ve)     |        |
#   linear_variance_31  |  0.9886  |     (+ve)     |        |
#   linear_variance_32  |  0.6110  |     (+ve)     |        |
#   linear_variance_33  |  1.1517  |     (+ve)     |        |
#   linear_variance_34  |  1.1874  |     (+ve)     |        |
#   linear_variance_35  |  2.2720  |     (+ve)     |        |
#   linear_variance_36  |  1.5698  |     (+ve)     |        |
#   linear_variance_37  |  0.5255  |     (+ve)     |        |
#   linear_variance_38  |  0.5806  |     (+ve)     |        |
#   linear_variance_39  |  1.3871  |     (+ve)     |        |
#   linear_variance_40  |  1.0735  |     (+ve)     |        |
#   linear_variance_41  |  1.0636  |     (+ve)     |        |
#   linear_variance_42  |  0.1811  |     (+ve)     |        |
#   linear_variance_43  |  0.6811  |     (+ve)     |        |
#   linear_variance_44  |  0.3907  |     (+ve)     |        |
#   linear_variance_45  |  0.8429  |     (+ve)     |        |
#   linear_variance_46  |  0.6453  |     (+ve)     |        |
#   linear_variance_47  |  1.2484  |     (+ve)     |        |
#   linear_variance_48  |  0.8643  |     (+ve)     |        |
#   linear_variance_49  |  1.1617  |     (+ve)     |        |
#   linear_variance_50  |  0.4869  |     (+ve)     |        |
#   linear_variance_51  |  0.3285  |     (+ve)     |        |
#     noise_variance    |  0.5090  |     (+ve)     |        |

# %% [markdown]
# ## Evaluation

# %%
def evaluate_on_ws(gp, ws, prt):
    n_plot_samples = 30

    force = ws.force[prt]
    skin = ws.skin[prt]
    valid = ws.valid[prt]

    def gp_predict(skin):
        force, force_conf, _, _ = gp.predict(skin.T, full_cov=False)
        return force[:, 0], force_conf[:, 0]

    p_force, p_force_conf = ws.predict_multicurve(gp_predict, force, skin, valid, what='force')
    print "MSE: ", multistep_error(p_force, force, valid, mean_err=True)

    ml.apps.skin.timeseries.max_force = 10
    plot_multicurve_time(force[:, 0:n_plot_samples], None, valid[:, 0:n_plot_samples], 
                         force_predicted=p_force[:, 0:n_plot_samples], force_predicted_conf=p_force_conf[:, 0:n_plot_samples])

# %%
figsize(16, 8)
evaluate_on_ws(gp, ws_linear_raising, 'trn')
# Out:
# MSE:  0.162183040884

# %%
figsize(16, 8)
evaluate_on_ws(gp, ws_linear_bidir, 'trn')
# Out:
# MSE:  0.235480110222

# %%
figsize(16, 8)
evaluate_on_ws(gp, ws_random_raising, 'trn')
# Out:
# MSE:  0.261355785331

# %%
figsize(16, 8)
evaluate_on_ws(gp, ws_random_bidir, 'trn')
# Out:
# MSE:  0.240943931267
