# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

import rbm.sampling

# %%
plot([1,2,3])
axis([0, 5, 0, 5])
gca().add_patch(Rectangle((0.9,1),0.2,3, fill=False))
#gca().add_patch(Line2D([0.9, 1.1], [2.5, 2.5]))
hlines(2.5, 0.9, 1.1, colors='r')

# %%
plt.figsize(10,5)
s1 = rbm.sampling.Stability("bla1", 1000, 910, 0.94, 4, 2)
s2 = rbm.sampling.Stability("bla2", 5000, 4650, 0.94, 4, 4)
rbm.sampling.plot_stability([s1, s2, s2, s2, s1])

# %%
range(1,2)
# Out:
# [1]
