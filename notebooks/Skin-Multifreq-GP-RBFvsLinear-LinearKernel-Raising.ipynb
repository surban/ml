# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import GPy as gpy

import ml.apps.skin.timeseries
from ml.apps.skin.timeseries import *
from ml.apps.skin.workingset import *
from ml.simple.conditional_chain import *
from ml.datasets.skin import SkinDataset
from ml.common.util import ParameterHistory
from ml.common.test import check_gradient, check_directional_gradient

ml.apps.skin.timeseries.max_force = 10
# Out:
# common.gpu uses GPU:  False

# %% [markdown]
# ## Dataset

# %%
ws_linear_bidir = SkinWorkingset("mf_linear_bidir_10", taxel=(0,6))
ws_linear_raising = SkinWorkingset("mf_linear_raising_10", taxel=(0,6))

ws_random_raising = SkinWorkingset("mf_random_raising_10", taxel=(0,6))
ws_random_bidir = SkinWorkingset("mf_random_bidir_10", taxel=(0,6))
# Out:
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_linear_bidir_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 38
# Sampling interval:          1 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   0.213234
# maximum force:   9.738249
# minimum skin:    -1.670687
# maximum skin:    4.811076
#
# force step:   0.095250
# skin step:    0.064818
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_linear_raising_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 19
# Sampling interval:          1 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   0.641865
# maximum force:   9.734317
# minimum skin:    -1.669979
# maximum skin:    4.805637
#
# force step:   0.090925
# skin step:    0.064756
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_random_raising_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 17
# Sampling interval:          0.666667 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   -0.100000
# maximum force:   8.456289
# minimum skin:    -1.669744
# maximum skin:    4.809771
#
# force step:   0.085563
# skin step:    0.064795
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_random_bidir_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 17
# Sampling interval:          0.625 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   -0.100000
# maximum force:   8.495613
# minimum skin:    -1.664976
# maximum skin:    4.807362
#
# force step:   0.085956
# skin step:    0.064723

# %% [markdown]
# ## Training

# %%
ws_trn = ws_linear_raising

#kernel = gpy.kern.rbf(ws_trn.n_features, ARD=False)
kernel = gpy.kern.linear(ws_trn.n_features, ARD=True)
X = ws_trn.flat_skin['trn'].T
Y = ws_trn.flat_force['trn'][:, np.newaxis]
gp = gpy.models.GPRegression(X, Y, kernel)

gp.optimize_restarts()
#gp.randomize()
#gp.optimize()
print gp
# Out:
# Optimization restart 1/10, f = 193.561302672
# Optimization restart 2/10, f = 222.72850698
# Optimization restart 3/10, f = 212.963528314
# Optimization restart 4/10, f = 163.946655318
# Optimization restart 5/10, f = 172.096332708
# Optimization restart 6/10, f = 157.429922284
# Optimization restart 7/10, f = 190.257001323
# Optimization restart 8/10, f = 140.99212317
# Optimization restart 9/10, f = 216.863311176
# Optimization restart 10/10, f = 186.154612129
# Log-likelihood: -1.410e+02
#
#          Name         |  Value   |  Constraints  |  Ties  |  prior
# --------------------------------------------------------------------
#   linear_variance_0   |  0.9702  |     (+ve)     |        |
#   linear_variance_1   |  1.0657  |     (+ve)     |        |
#   linear_variance_2   |  0.1889  |     (+ve)     |        |
#   linear_variance_3   |  0.5950  |     (+ve)     |        |
#   linear_variance_4   |  1.2271  |     (+ve)     |        |
#   linear_variance_5   |  0.1681  |     (+ve)     |        |
#   linear_variance_6   |  0.9054  |     (+ve)     |        |
#   linear_variance_7   |  0.0997  |     (+ve)     |        |
#   linear_variance_8   |  0.3073  |     (+ve)     |        |
#   linear_variance_9   |  0.7126  |     (+ve)     |        |
#   linear_variance_10  |  0.1746  |     (+ve)     |        |
#   linear_variance_11  |  0.3172  |     (+ve)     |        |
#   linear_variance_12  |  0.2066  |     (+ve)     |        |
#   linear_variance_13  |  1.8241  |     (+ve)     |        |
#   linear_variance_14  |  0.7786  |     (+ve)     |        |
#   linear_variance_15  |  1.0165  |     (+ve)     |        |
#   linear_variance_16  |  0.5880  |     (+ve)     |        |
#   linear_variance_17  |  0.5320  |     (+ve)     |        |
#   linear_variance_18  |  0.1812  |     (+ve)     |        |
#   linear_variance_19  |  0.5578  |     (+ve)     |        |
#   linear_variance_20  |  0.3832  |     (+ve)     |        |
#   linear_variance_21  |  1.2114  |     (+ve)     |        |
#   linear_variance_22  |  1.4183  |     (+ve)     |        |
#   linear_variance_23  |  1.6742  |     (+ve)     |        |
#   linear_variance_24  |  1.2077  |     (+ve)     |        |
#   linear_variance_25  |  0.4380  |     (+ve)     |        |
#   linear_variance_26  |  0.2834  |     (+ve)     |        |
#   linear_variance_27  |  1.1482  |     (+ve)     |        |
#   linear_variance_28  |  0.8871  |     (+ve)     |        |
#   linear_variance_29  |  0.1575  |     (+ve)     |        |
#   linear_variance_30  |  0.8866  |     (+ve)     |        |
#   linear_variance_31  |  1.1811  |     (+ve)     |        |
#   linear_variance_32  |  0.7230  |     (+ve)     |        |
#   linear_variance_33  |  0.6049  |     (+ve)     |        |
#   linear_variance_34  |  0.3687  |     (+ve)     |        |
#   linear_variance_35  |  0.2114  |     (+ve)     |        |
#   linear_variance_36  |  1.1713  |     (+ve)     |        |
#   linear_variance_37  |  0.5505  |     (+ve)     |        |
#   linear_variance_38  |  0.5832  |     (+ve)     |        |
#   linear_variance_39  |  1.8955  |     (+ve)     |        |
#   linear_variance_40  |  1.0929  |     (+ve)     |        |
#   linear_variance_41  |  0.8957  |     (+ve)     |        |
#   linear_variance_42  |  0.7667  |     (+ve)     |        |
#   linear_variance_43  |  1.7178  |     (+ve)     |        |
#   linear_variance_44  |  1.8844  |     (+ve)     |        |
#   linear_variance_45  |  1.2622  |     (+ve)     |        |
#   linear_variance_46  |  1.0260  |     (+ve)     |        |
#   linear_variance_47  |  0.1161  |     (+ve)     |        |
#   linear_variance_48  |  0.7569  |     (+ve)     |        |
#   linear_variance_49  |  0.6302  |     (+ve)     |        |
#   linear_variance_50  |  0.7412  |     (+ve)     |        |
#   linear_variance_51  |  1.2719  |     (+ve)     |        |
#     noise_variance    |  0.0626  |     (+ve)     |        |

# %% [markdown]
# ## Evaluation

# %%
def evaluate_on_ws(gp, ws, prt):
    n_plot_samples = 30

    force = ws.force[prt]
    skin = ws.skin[prt]
    valid = ws.valid[prt]

    def gp_predict(skin):
        force, force_conf, _, _ = gp.predict(skin.T, full_cov=False)
        return force[:, 0], force_conf[:, 0]

    p_force, p_force_conf = ws.predict_multicurve(gp_predict, force, skin, valid, what='force')
    print "MSE: ", multistep_error(p_force, force, valid, mean_err=True)

    ml.apps.skin.timeseries.max_force = 10
    plot_multicurve_time(force[:, 0:n_plot_samples], None, valid[:, 0:n_plot_samples], 
                         force_predicted=p_force[:, 0:n_plot_samples], force_predicted_conf=p_force_conf[:, 0:n_plot_samples])

# %%
figsize(16, 8)
evaluate_on_ws(gp, ws_linear_raising, 'trn')
# Out:
# MSE:  0.0411557658214

# %%
figsize(16, 8)
evaluate_on_ws(gp, ws_linear_bidir, 'trn')
# Out:
# MSE:  0.399803032436

# %%
figsize(16, 8)
evaluate_on_ws(gp, ws_random_raising, 'trn')
# Out:
# MSE:  0.172940594829

# %%
figsize(16, 8)
evaluate_on_ws(gp, ws_random_bidir, 'trn')
# Out:
# MSE:  0.482722693978
