# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import GPy as gpy

import ml.apps.skin.timeseries
from ml.apps.skin.timeseries import *
from ml.apps.skin.workingset import *
from ml.simple.conditional_chain import *
from ml.datasets.skin import SkinDataset

ml.apps.skin.timeseries.max_force = 10
# Out:
# common.gpu uses GPU:  False

# %% [markdown]
# ## Dataset and features selection

# %%
def select_features(ws, skin):    
    return ws.select_frequencies([794328, 2511886], skin)

force_min = -0.2
force_max = 10.0

ws_linear_bidir = SkinWorkingset("mf_linear_bidir_10", taxel=(0,6), force_min=force_min, force_max=force_max)
ws_linear_raising = SkinWorkingset("mf_linear_raising_10", taxel=(0,6), force_min=force_min, force_max=force_max)

ws_random_raising = SkinWorkingset("mf_random_raising_10", taxel=(0,6), force_min=force_min, force_max=force_max)
ws_random_bidir = SkinWorkingset("mf_random_bidir_10", taxel=(0,6), force_min=force_min, force_max=force_max)

ws_hysteresis_10 = SkinWorkingset("mf_hysteresis_10", taxel=(0,6), force_min=force_min, force_max=force_max)
ws_hysteresis_50 = SkinWorkingset("mf_hysteresis_50", taxel=(0,6), force_min=force_min, force_max=force_max)
ws_hysteresis_100 = SkinWorkingset("mf_hysteresis_100", taxel=(0,6), force_min=force_min, force_max=force_max)
# Out:
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_linear_bidir_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 38
# Sampling interval:          1 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   -0.200000
# maximum force:   10.000000
# minimum skin:    -1.670687
# maximum skin:    4.811076
#
# force step:   0.102000
# skin step:    0.064818
#
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_linear_raising_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 19
# Sampling interval:          1 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   -0.200000
# maximum force:   10.000000
# minimum skin:    -1.669979
# maximum skin:    4.805637
#
# force step:   0.102000
# skin step:    0.064756
#
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_random_raising_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 17
# Sampling interval:          0.666667 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   -0.200000
# maximum force:   10.000000
# minimum skin:    -1.669744
# maximum skin:    4.809771
# force step:   0.102000
# skin step:    0.064795
#
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_random_bidir_10.skn:
#      taxel          train   validation   test
#      0,6              8       1            1
# Avg. datapoints per record: 17
# Sampling interval:          0.625 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             8
# val: curves:             1
# tst: curves:             1
#
# minimum force:   -0.200000
# maximum force:   10.000000
# minimum skin:    -1.664976
# maximum skin:    4.807362
#
# force step:   0.102000
# skin step:    0.064723
#
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_hysteresis_10.skn:
#      taxel          train   validation   test
#      0,6             16       2            2
# Avg. datapoints per record: 40
# Sampling interval:          1 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             16
# val: curves:             2
# tst: curves:             2
#
# minimum force:   -0.200000
# maximum force:   10.000000
# minimum skin:    -1.670060
# maximum skin:    4.810099
#
# force step:   0.102000
# skin step:    0.064802
#
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_hysteresis_50.skn:
#      taxel          train   validation   test
#      0,6             40       5            5
# Avg. datapoints per record: 37
# Sampling interval:          1 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             40
# val: curves:             5
# tst: curves:             5
#
# minimum force:   -0.200000
# maximum force:   10.000000
# minimum skin:    -1.670131
# maximum skin:    4.812385
#
# force step:   0.102000
# skin step:    0.064825
#
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_hysteresis_100.skn:
#      taxel          train   validation   test
#      0,6             80      10           10
# Avg. datapoints per record: 37
# Sampling interval:          1 s
# Stimulus frequencies:
# [    0.      794.328  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             80
# val: curves:             10
# tst: curves:             10
#
# minimum force:   -0.200000
# maximum force:   10.000000
# minimum skin:    -1.670612
# maximum skin:    4.812298
#
# force step:   0.102000
# skin step:    0.064829

# %% [markdown]
# ## Model creation

# %%
ws_base = ws_linear_bidir
base_obs = select_features(ws_base, ws_base.skin['trn'])
n_features = base_obs.shape[0]

sc = ControlObservationChain(ws_base.discrete_force_states, ws_base.discrete_force_states)

# %% [markdown]
# ## Pretraining of observation -> state model using hysteresis-free data

# %%
ws_raising_trn = ws_linear_raising

states = ws_raising_trn.discrete_force['trn']
observations = select_features(ws_raising_trn, ws_raising_trn.skin['trn'])
valid = ws_raising_trn.valid['trn']

sc.train_observations(states, observations, valid,                      
                      kernel=lambda: gpy.kern.rbf(n_features),
                      optimize_restarts=10)  
print sc.gp_states_given_observations
# Out:
# Optimization restart 1/10, f = -19.9763844614
# Optimization restart 2/10, f = -62.8784857177
# Optimization restart 3/10, f = -68.9669600751
# Optimization restart 4/10, f = -44.0935081653
# Optimization restart 5/10, f = -126.132309967
# Optimization restart 6/10, f = -98.4220005997
# Optimization restart 7/10, f = 41.472661166
# Warning: adding jitter of 4.0860117796e-07
# Optimization restart 8/10, f = -85.0526395639
# Optimization restart 9/10, f = -1.39855360548
# Optimization restart 10/10, f = -64.6282674274
# Log-likelihood: 1.261e+02
#
#        Name        |  Value   |  Constraints  |  Ties  |  prior
# -----------------------------------------------------------------
#    rbf_variance    |  0.0486  |     (+ve)     |        |
#   rbf_lengthscale  |  0.7312  |     (+ve)     |        |
#   noise_variance   |  0.0032  |     (+ve)     |        |
# C:\Anaconda\lib\site-packages\numpy\core\_methods.py:79: RuntimeWarning: Degrees of freedom <= 0 for slice
#   warnings.warn("Degrees of freedom <= 0 for slice", RuntimeWarning)

# %% [markdown]
# #### Evaluation

# %%
def evaluate_on_ws(sc, ws, prt, phase=False):
    n_plot_samples = 30

    force = ws.force[prt]
    skin = select_features(ws, ws.skin[prt])
    valid = ws.valid[prt]

    p_force_discr, p_force_conf_discr = ws.predict_multicurve(sc.infer_states, force, skin, valid, what='force')
    p_force = ws.from_discrete_force(p_force_discr)
    p_force_conf = p_force_conf_discr * ws.force_step
    print "MSE: ", multistep_error(p_force, force, valid, mean_err=True)
    
    ml.apps.skin.timeseries.max_force = 10
    if phase:
        plot_multicurve_error(force[:, 0:n_plot_samples], p_force[:, 0:n_plot_samples], valid[:, 0:n_plot_samples])
    else:
        plot_multicurve_time(force[:, 0:n_plot_samples], None, valid[:, 0:n_plot_samples], 
                             force_predicted=p_force[:, 0:n_plot_samples], force_predicted_conf=p_force_conf[:, 0:n_plot_samples])    
        
figsize(16, 8)
evaluate_on_ws(sc, ws_hysteresis_10, 'trn')
# Out:
# MSE:  0.221104699554

# %% [markdown]
# ## Training of state -> state model using data with hysteresis

# %%
ws_hys_trn = ws_hysteresis_100

discrete_force = ws_hys_trn.discrete_force['trn']
observations = select_features(ws_hys_trn, ws_hys_trn.skin['trn'])
valid = ws_hys_trn.valid['trn']

states, _ = iterate_over_samples(sc.infer_states, valid, observations)
states = np.asarray(states, dtype='int')

sc.train_transitions(states, discrete_force, valid, 
                     mngful_dist=4, 
                     kernel=lambda: gpy.kern.rbf(1) + gpy.kern.linear(1), 
                     optimize_restarts=3)                     

sc.check_normalization()
# Out:
# Initial state:  5.55111512313e-17

# %%
sc.initialize_transitions(sigma=5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-11e6d23f0d93> in <module>()
# ----> 1 sc.initialize_transitions(sigma=5)
#
# AttributeError: 'ControlObservationChain' object has no attribute 'initialize_transitions'

# %% [markdown]
# #### Evaluation: states from inputs

# %%
ws_hys_tst = ws_hysteresis_100
prt = 'tst'

discrete_force = ws_hys_tst.discrete_force[prt]
observations = select_features(ws_hys_tst, ws_hys_tst.skin[prt])
valid = ws_hys_tst.valid[prt]

states, _ = iterate_over_samples(sc.infer_states, valid, observations)
p_states, p_log_p = iterate_over_samples(sc.most_probable_states_given_inputs, valid, discrete_force) 

print "MSE: ", multistep_error(ws_hys_tst.from_discrete_force(p_states), 
                               ws_hys_trn.from_discrete_force(states), valid, mean_err=True)

n_plot_smpls = 42
figsize(18,14)
ml.apps.skin.timeseries.max_force = 10
force_real = ws_hys_tst.from_discrete_force(discrete_force[:, 0:n_plot_smpls])
plot_multicurve_time(ws_hys_tst.from_discrete_force(states[:, 0:n_plot_smpls]), None, valid[:, 0:n_plot_smpls], 
                     force_predicted=ws_hys_tst.from_discrete_force(p_states[:, 0:n_plot_smpls]), 
                     force_real=force_real,
                     timestep=ws_hys_tst.ds.timestep)
# Out:
# MSE:  0.0333281517428

# %% [markdown]
# #### Evalulation: states and inputs from observations

# %%
force = ws_hys_tst.force[prt]
observations = select_features(ws_hys_tst, ws_hys_tst.skin[prt])
valid = ws_hys_tst.valid[prt]

p_states, p_discrete_force, p_log_p = iterate_over_samples(sc.most_probable_states_and_inputs_given_observations, valid, observations) 
p_force = ws_hys_tst.from_discrete_force(p_discrete_force)
p_internal_force = ws_hys_tst.from_discrete_force(p_states)

print "MSE: ", multistep_error(p_force, force, valid, mean_err=True)

n_plot_smpls = 42
figsize(18,14)
ml.apps.skin.timeseries.max_force = 10
plot_multicurve_time(force[:, 0:n_plot_smpls], None, valid[:, 0:n_plot_smpls], 
                     force_predicted=p_force[:, 0:n_plot_smpls], 
                     force_real=p_internal_force[:, 0:n_plot_smpls],
                     timestep=ws_hys_tst.ds.timestep)
# Out:
# MSE:  0.0570383898766

# %% [markdown]
# ## Iterative state estimation and training of observation and transition models

# %%
# prepare data
n_smpls = 10
discrete_force = ws_hys_trn.discrete_force['trn'][..., 0:n_smpls]
observations = select_features(ws_hys_trn, ws_hys_trn.skin['trn'][..., 0:n_smpls])
valid = ws_hys_trn.valid['trn'][..., 0:n_smpls]

# estimate state using current weights
print "Estimating state..."""
p_states, p_log_p = iterate_over_samples(sc.most_probable_states_given_inputs_and_observations, 
                                         valid, discrete_force, observations)

# train observation GP
print "Training observation GP..."
sc.train_observations(p_states, observations, valid,                      
                      kernel=lambda: gpy.kern.rbf(n_features),
                      finetune=True)  

# train transition GPs
print "Training transition GPs..."
sc.train_transitions(p_states, discrete_force, valid, 
                     mngful_dist=4, 
                     kernel=lambda: gpy.kern.rbf(1) + gpy.kern.linear(1), 
                     finetune=True)

# %%
p_states, p_log_p = iterate_over_samples(sc.most_probable_states_given_inputs_and_observations, 
                                         valid, discrete_force, observations)

n_plot_smpls = 42
figsize(18,14)
ml.apps.skin.timeseries.max_force = 10
plot_multicurve_time(ws_hys_trn.from_discrete_force(discrete_force[:, 0:n_plot_smpls]), 
                     None, valid[:, 0:n_plot_smpls], 
                     force_predicted=ws_hys_trn.from_discrete_force(p_states[:, 0:n_plot_smpls]), 
                     timestep=ws_hys_tst.ds.timestep)

# %%
print sc.gp_states_given_observations.gp['rbf_variance']
# Out:
# [ 0.049]

# %%
a = sc.gp_states_given_observations.gp._get_param_names()

print a
# Out:
# ['rbf_variance', 'rbf_lengthscale', 'noise_variance']

# %%
print sc.gp_states_given_observations.gp
# Out:
# Log-likelihood: 2.051e+02
#
#        Name        |  Value   |  Constraints  |  Ties  |  prior
# -----------------------------------------------------------------
#    rbf_variance    |  0.0486  |     (+ve)     |        |
#   rbf_lengthscale  |  0.7312  |     (+ve)     |        |
#   noise_variance   |  0.0032  |     (+ve)     |        |
