# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt
import GPy as gpy

import ml.apps.skin.timeseries
from ml.apps.skin.timeseries import *
from ml.apps.skin.workingset import *
from ml.simple.conditional_chain import *
from ml.datasets.skin import SkinDataset
from ml.common.util import ParameterHistory
from ml.common.test import check_gradient, check_directional_gradient

ml.apps.skin.timeseries.max_force = 10
# Out:
# common.gpu uses GPU:  False

# %% [markdown]
# ## Dataset

# %%
ws = SkinWorkingset("mf_small1", taxel=(0,6), curve_limit=160)
ws_raising = SkinWorkingset("mf_raising_small1", taxel=(0,6))
# Out:
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_small1.skn:
#      taxel          train   validation   test
#      0,6            201      25           25
# Avg. datapoints per record: 17
# Sampling interval:          0.588235 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             160
# val: curves:             25
# tst: curves:             25
#
# minimum force:   -0.100000
# maximum force:   10.248149
# minimum skin:    -1.670399
# maximum skin:    4.812214
#
# force step:   0.103481
# skin step:    0.064826
# Dataset \\brml.tum.de\dfs\nthome\surban\dev\indentor\indentor\apps\out\mf_raising_small1.skn:
#      taxel          train   validation   test
#      0,6            198      24           24
# Avg. datapoints per record: 17
# Sampling interval:          0.625 s
# Stimulus frequencies:
# [    0.       10.       12.589    15.849    19.953    25.119    31.623
#     39.811    50.119    63.096    79.433   100.      125.893   158.489
#    199.526   251.189   316.228   398.107   501.187   630.957   794.328
#   1000.     1258.925  1584.893  1995.262  2511.886] kHz
#
# Using taxel  (0, 6)
#
# trn: curves:             198
# val: curves:             24
# tst: curves:             24
#
# minimum force:   -0.100000
# maximum force:   10.325487
# minimum skin:    -1.670708
# maximum skin:    4.812367
#
# force step:   0.104255
# skin step:    0.064831

# %% [markdown]
# ## Training

# %%
kernel = gpy.kern.rbf(ws.n_features, ARD=False)
X = ws.flat_skin['trn'].T
Y = ws.flat_force['trn'][:, np.newaxis]
gp = gpy.models.GPRegression(X, Y, kernel)

#gp.optimize()
gp.optimize_restarts()
print gp

# %% [markdown]
# ## Evaluation

# %%
prt = 'tst'
n_plot_samples = 30

force = ws.force[prt]
skin = ws.skin[prt]
valid = ws.valid[prt]

def gp_predict(skin):
    force, force_conf, _, _ = gp.predict(skin.T, full_cov=False)
    return force[:, 0], force_conf[:, 0]

p_force, p_force_conf = ws.predict_multicurve(gp_predict, force, skin, valid, what='force')
print "MSE: ", multistep_error(p_force, force, valid, mean_err=True)

figsize(16, 8)
ml.apps.skin.timeseries.max_force = 10
plot_multicurve_time(force[:, 0:n_plot_samples], None, valid, 
                     force_predicted=p_force[:, 0:n_plot_samples], force_predicted_conf=p_force_conf[:, 0:n_plot_samples])
# Out:
# MSE:  0.0893143913295

# %% [markdown]
# ## Evaluation on raising dataset

# %%
prt = 'tst'
n_plot_samples = 30

force = ws_raising.force[prt]
skin = ws_raising.skin[prt]
valid = ws_raising.valid[prt]

def gp_predict(skin):
    force, force_conf, _, _ = gp.predict(skin.T, full_cov=False)
    return force[:, 0], force_conf[:, 0]

p_force, p_force_conf = ws_raising.predict_multicurve(gp_predict, force, skin, valid, what='force')
print "MSE: ", multistep_error(p_force, force, valid, mean_err=True)

ml.apps.skin.timeseries.max_force = 10
plot_multicurve_time(force[:, 0:n_plot_samples], None, valid, 
                     force_predicted=p_force[:, 0:n_plot_samples], force_predicted_conf=p_force_conf[:, 0:n_plot_samples])
# Out:
# MSE:  3.2568184402

# %% [markdown]
# ## Misc

# %%
plt.hold(True)
plt.plot(ws.curves['trn'][1][0, :])
plt.plot(10 * ws.curves['trn'][1][39, :])
plt.plot(10 - 10 * ws.curves['trn'][1][40, :])
