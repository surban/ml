# %%
# %load_ext autoreload
# %autoreload 2

import apps.generate_letters
import numpy as np

# %%
img=apps.generate_letters.generate_letters()[1]
pylab.imshow(img, cmap='gray')

# %%
ds = apps.generate_letters.generate_letter_dataset()
